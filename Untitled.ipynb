# %%
from rdkit import Chem
from rdkit.Chem import rdMolDescriptors

# %%
x = Chem.MolFromSmiles('C1C=CC=C1c1cc2[se]c3c4occc4c4nsnc4c3c2cn1')
x

# %%
rdMolDescriptors.CalcMolFormula(x)
# Out:
# 'C18H9N3OSSe'
